# %%
from sympy import Add, Mul, symbols, sympify, I, ccode, expand, diff, simplify, re, im

def handle_re_im(expr):
    """Recursively replace re and im functions with their definitions."""
    # Base condition: If there are no 're' or 'im' functions in the expression, return the expression as is
    if not (expr.has(re) or expr.has(im)):
        return expr

    # Replace re and im functions with their definitions
    new_expr = expr.replace(re, lambda arg: arg.as_real_imag()[0])
    new_expr = new_expr.replace(im, lambda arg: arg.as_real_imag()[1])

    # Recursive call to handle nested re and im functions
    return handle_re_im(new_expr)

def compute_derivatives_updated(expr_str, var='z', real_var='x', imag_var='y', param='w'):
    x, y, a = symbols(f'{real_var} {imag_var} {param}', real=True)
    z = x + I*y
    expr = sympify(expr_str)
    expr = expr.subs(var, z)
    expr = handle_re_im(expr)  # Handle re and im in the expression
    expr_expanded = expand(expr)
    f_real = expr_expanded.as_real_imag()[0]
    f_imag = expr_expanded.as_real_imag()[1]

    f_prime_real_x = diff(f_real, x)
    f_prime_real_y = diff(f_real, y)
    f_prime_imag_x = diff(f_imag, x)
    f_prime_imag_y = diff(f_imag, y)

    return f_real, f_imag, f_prime_real_x, f_prime_real_y, f_prime_imag_x, f_prime_imag_y

# Example Usage:

f = "sin(cos(z*z*z)*z*z)/cos(z)-1"
f_real_updated, f_imag_updated, f_prime_real_x_updated, f_prime_real_y_updated, f_prime_imag_x_updated, f_prime_imag_y_updated = compute_derivatives_updated(f)

# Names for display
names = ["f_real", "f_imag", "f_prime_real_x", "f_prime_real_y", "f_prime_imag_x", "f_prime_imag_y"]

outputs_updated = []
for name, q in zip(names, [f_real_updated, f_imag_updated, f_prime_real_x_updated, f_prime_real_y_updated, f_prime_imag_x_updated, f_prime_imag_y_updated]):
    outputs_updated.append((name, q))

outputs_updated
# Out:
# [('f_real',
#   re(sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) - 1),
#  ('f_imag',
#   im(sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y))),
#  ('f_prime_real_x',
#   -(-6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + re(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2)),
#  ('f_prime_real_y',
#   (6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) - (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) - im(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2)),
#  ('f_prime_imag_x',
#   (-6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + im(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2)),
#  ('f_prime_imag_y',
#   (6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + re(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2))]

# %%
def handle_re_im_and_I(expr):
    """Recursively replace re, im functions and I (imaginary unit) with their definitions."""
    
    # Handle re and im as before
    new_expr = handle_re_im(expr)
    
    # Check if the expression contains I (imaginary unit)
    if new_expr.has(I):
        # Expand and separate into real and imaginary parts
        real_part, imag_part = new_expr.as_real_imag()
        
        # Replace the expression with its separated real and imaginary components
        new_expr = real_part + I*imag_part
        
        # Recursive call to handle further occurrences of I
        return handle_re_im_and_I(new_expr)
    
    return new_expr

# Update the compute_derivatives function to handle re, im, and I
def compute_derivatives_updated_v2(expr_str, var='z', real_var='x', imag_var='y', param='w'):
    x, y, a = symbols(f'{real_var} {imag_var} {param}', real=True)
    z = x + I*y
    expr = sympify(expr_str)
    expr = expr.subs(var, z)
    expr = handle_re_im_and_I(expr)  # Handle re, im, and I in the expression
    expr_expanded = expand(expr)
    f_real = expr_expanded.as_real_imag()[0]
    f_imag = expr_expanded.as_real_imag()[1]

    f_prime_real_x = diff(f_real, x)
    f_prime_real_y = diff(f_real, y)
    f_prime_imag_x = diff(f_imag, x)
    f_prime_imag_y = diff(f_imag, y)

    return f_real, f_imag, f_prime_real_x, f_prime_real_y, f_prime_imag_x, f_prime_imag_y

# Test the updated function
f_real_updated_v2, f_imag_updated_v2, f_prime_real_x_updated_v2, f_prime_real_y_updated_v2, f_prime_imag_x_updated_v2, f_prime_imag_y_updated_v2 = compute_derivatives_updated_v2(f)

# Names for display
outputs_updated_v2 = []
for name, q in zip(names, [f_real_updated_v2, f_imag_updated_v2, f_prime_real_x_updated_v2, f_prime_real_y_updated_v2, f_prime_imag_x_updated_v2, f_prime_imag_y_updated_v2]):
    outputs_updated_v2.append((name, q))

outputs_updated_v2
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[16], line 39
#      36     return f_real, f_imag, f_prime_real_x, f_prime_real_y, f_prime_imag_x, f_prime_imag_y
#      38 # Test the updated function
# ---> 39 f_real_updated_v2, f_imag_updated_v2, f_prime_real_x_updated_v2, f_prime_real_y_updated_v2, f_prime_imag_x_updated_v2, f_prime_imag_y_updated_v2 = compute_derivatives_updated_v2(f)
#      41 # Names for display
#      42 outputs_updated_v2 = []
#
# Cell In[16], line 26, in compute_derivatives_updated_v2(expr_str, var, real_var, imag_var, param)
#      24 expr = sympify(expr_str)
#      25 expr = expr.subs(var, z)
# ---> 26 expr = handle_re_im_and_I(expr)  # Handle re, im, and I in the expression
#      27 expr_expanded = expand(expr)
#      28 f_real = expr_expanded.as_real_imag()[0]
#
# Cell In[16], line 16, in handle_re_im_and_I(expr)
#      13     new_expr = real_part + I*imag_part
#      15     # Recursive call to handle further occurrences of I
# ---> 16     return handle_re_im_and_I(new_expr)
#      18 return new_expr
#
# Cell In[16], line 5, in handle_re_im_and_I(expr)
#       2 """Recursively replace re, im functions and I (imaginary unit) with their definitions."""
#       4 # Handle re and im as before
# ----> 5 new_expr = handle_re_im(expr)
#       7 # Check if the expression contains I (imaginary unit)
#       8 if new_expr.has(I):
#       9     # Expand and separate into real and imaginary parts
#
# Cell In[15], line 14, in handle_re_im(expr)
#      11 new_expr = new_expr.replace(im, lambda arg: arg.as_real_imag()[1])
#      13 # Recursive call to handle nested re and im functions
# ---> 14 return handle_re_im(new_expr)
#
# Cell In[15], line 14, in handle_re_im(expr)
#      11 new_expr = new_expr.replace(im, lambda arg: arg.as_real_imag()[1])
#      13 # Recursive call to handle nested re and im functions
# ---> 14 return handle_re_im(new_expr)
#
#     [... skipping similar frames: handle_re_im at line 14 (2923 times)]
#
# Cell In[15], line 14, in handle_re_im(expr)
#      11 new_expr = new_expr.replace(im, lambda arg: arg.as_real_imag()[1])
#      13 # Recursive call to handle nested re and im functions
# ---> 14 return handle_re_im(new_expr)
#
# Cell In[15], line 11, in handle_re_im(expr)
#       9 # Replace re and im functions with their definitions
#      10 new_expr = expr.replace(re, lambda arg: arg.as_real_imag()[0])
# ---> 11 new_expr = new_expr.replace(im, lambda arg: arg.as_real_imag()[1])
#      13 # Recursive call to handle nested re and im functions
#      14 return handle_re_im(new_expr)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1666, in Basic.replace(self, query, value, map, simultaneous, exact)
#    1663             expr = v
#    1664     return expr
# -> 1666 rv = walk(self, rec_replace)
#    1667 return (rv, mapping) if map else rv
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1641, in Basic.replace.<locals>.walk(rv, F)
#    1639 if args is not None:
#    1640     if args:
# -> 1641         newargs = tuple([walk(a, F) for a in args])
#    1642         if args != newargs:
#    1643             rv = rv.func(*newargs)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1641, in <listcomp>(.0)
#    1639 if args is not None:
#    1640     if args:
# -> 1641         newargs = tuple([walk(a, F) for a in args])
#    1642         if args != newargs:
#    1643             rv = rv.func(*newargs)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1641, in Basic.replace.<locals>.walk(rv, F)
#    1639 if args is not None:
#    1640     if args:
# -> 1641         newargs = tuple([walk(a, F) for a in args])
#    1642         if args != newargs:
#    1643             rv = rv.func(*newargs)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1641, in <listcomp>(.0)
#    1639 if args is not None:
#    1640     if args:
# -> 1641         newargs = tuple([walk(a, F) for a in args])
#    1642         if args != newargs:
#    1643             rv = rv.func(*newargs)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1651, in Basic.replace.<locals>.walk(rv, F)
#    1649                     if rv == e and e != newargs[i]:
#    1650                         return rv
# -> 1651     rv = F(rv)
#    1652 return rv
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1659, in Basic.replace.<locals>.rec_replace(expr)
#    1657 result = _query(expr)
#    1658 if result or result == {}:
# -> 1659     v = _value(expr, result)
#    1660     if v is not None and v != expr:
#    1661         if map:
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1588, in Basic.replace.<locals>.<lambda>(expr, result)
#    1586     _value = lambda expr, result: value(*expr.args)
#    1587 elif callable(value):
# -> 1588     _value = lambda expr, result: value(*expr.args)
#    1589 else:
#    1590     raise TypeError(
#    1591         "given a type, replace() expects another "
#    1592         "type or a callable")
#
# Cell In[15], line 11, in handle_re_im.<locals>.<lambda>(arg)
#       9 # Replace re and im functions with their definitions
#      10 new_expr = expr.replace(re, lambda arg: arg.as_real_imag()[0])
# ---> 11 new_expr = new_expr.replace(im, lambda arg: arg.as_real_imag()[1])
#      13 # Recursive call to handle nested re and im functions
#      14 return handle_re_im(new_expr)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/mul.py:849, in Mul.as_real_imag(self, deep, **hints)
#     847 addterms = S.One
#     848 for a in self.args:
# --> 849     r, i = a.as_real_imag()
#     850     if i.is_zero:
#     851         coeffr.append(r)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/power.py:1334, in Pow.as_real_imag(self, deep, **hints)
#    1331     r = [i for i in expr.terms() if i[0][1] % 4 == 3]
#    1332     im_part3 = Add(*[cc*a**aa*b**bb for (aa, bb), cc in r])
# -> 1334     return (re_part.subs({a: re_e, b: S.ImaginaryUnit*im_e}),
#    1335     im_part1.subs({a: re_e, b: im_e}) + im_part3.subs({a: re_e, b: -im_e}))
#    1337 from sympy.functions.elementary.trigonometric import atan2, cos, sin
#    1339 if self.exp.is_Rational:
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1040, in Basic.subs(self, *args, **kwargs)
#    1038 rv = self
#    1039 for old, new in sequence:
# -> 1040     rv = rv._subs(old, new, **kwargs)
#    1041     if not isinstance(rv, Basic):
#    1042         break
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1126, in Basic._subs.<locals>.fallback(self, old, new)
#    1124 if not hasattr(arg, '_eval_subs'):
#    1125     continue
# -> 1126 arg = arg._subs(old, new, **hints)
#    1127 if not _aresame(arg, args[i]):
#    1128     hit = True
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1126, in Basic._subs.<locals>.fallback(self, old, new)
#    1124 if not hasattr(arg, '_eval_subs'):
#    1125     continue
# -> 1126 arg = arg._subs(old, new, **hints)
#    1127 if not _aresame(arg, args[i]):
#    1128     hit = True
#
#     [... skipping similar frames: __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 72 (4 times), Basic._subs at line 1154 (3 times), Basic._subs.<locals>.fallback at line 1126 (3 times)]
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1154, in Basic._subs(self, old, new, **hints)
#    1152 rv = self._eval_subs(old, new)
#    1153 if rv is None:
# -> 1154     rv = fallback(self, old, new)
#    1155 return rv
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1126, in Basic._subs.<locals>.fallback(self, old, new)
#    1124 if not hasattr(arg, '_eval_subs'):
#    1125     continue
# -> 1126 arg = arg._subs(old, new, **hints)
#    1127 if not _aresame(arg, args[i]):
#    1128     hit = True
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:1149, in Basic._subs(self, old, new, **hints)
#    1146         return rv
#    1147     return self
# -> 1149 if _aresame(self, old):
#    1150     return new
#    1152 rv = self._eval_subs(old, new)
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:2138, in _aresame(a, b)
#    2136     return a == b and a.__class__ == b.__class__
#    2137 for i, j in zip_longest(_preorder_traversal(a), _preorder_traversal(b)):
# -> 2138     if i != j or type(i) != type(j):
#    2139         if ((isinstance(i, UndefFunc) and isinstance(j, UndefFunc)) or
#    2140             (isinstance(i, AppliedUndef) and isinstance(j, AppliedUndef))):
#    2141             if i.class_key() != j.class_key():
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:437, in Basic.__ne__(self, other)
#     428 def __ne__(self, other):
#     429     """``a != b``  -> Compare two symbolic trees and see whether they are different
#     430
#     431     this is the same as:
#    (...)
#     435     but faster
#     436     """
# --> 437     return not self == other
#
# File ~/code/reactflask/venv/lib64/python3.11/site-packages/sympy/core/basic.py:415, in Basic.__eq__(self, other)
#     411     return self._do_eq_sympify(other)
#     413 # check for pure number expr
#     414 if  not (self.is_Number and other.is_Number) and (
# --> 415         type(self) != type(other)):
#     416     return False
#     417 a, b = self._hashable_content(), other._hashable_content()
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
def handle_re_im_and_I(expr):
    """Recursively replace re, im functions and I (imaginary unit) with their definitions."""
    
    # Handle re and im as before
    new_expr = handle_re_im(expr)
    
    # If the expression has not changed and still contains I, then return it as is
    if new_expr == expr and new_expr.has(I):
        return new_expr
    
    # Otherwise, check if the expression contains I (imaginary unit)
    if new_expr.has(I):
        # Expand and separate into real and imaginary parts
        real_part, imag_part = new_expr.as_real_imag()
        
        # Replace the expression with its separated real and imaginary components
        new_expr = real_part + I*imag_part
        
        # Recursive call to handle further occurrences of I
        return handle_re_im_and_I(new_expr)
    
    return new_expr

# Test the updated function again
f_real_updated_v2, f_imag_updated_v2, f_prime_real_x_updated_v2, f_prime_real_y_updated_v2, f_prime_imag_x_updated_v2, f_prime_imag_y_updated_v2 = compute_derivatives_updated_v2(f)

# Names for display
outputs_updated_v2 = []
for name, q in zip(names, [f_real_updated_v2, f_imag_updated_v2, f_prime_real_x_updated_v2, f_prime_real_y_updated_v2, f_prime_imag_x_updated_v2, f_prime_imag_y_updated_v2]):
    outputs_updated_v2.append((name, q))

outputs_updated_v2
# Out:
# [('f_real',
#   re(sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) - 1),
#  ('f_imag',
#   im(sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y))),
#  ('f_prime_real_x',
#   -(-6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + re(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2)),
#  ('f_prime_real_y',
#   (6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) - (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) - im(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2)),
#  ('f_prime_imag_x',
#   (-6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + im(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2)),
#  ('f_prime_imag_y',
#   (6*x**3*y*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 12*x**2*y**2*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + x**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 6*x*y**3*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*x*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - y**2*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) - 2*y*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3))*im(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + (6*x**3*y*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 12*x**2*y**2*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - x**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) - 6*x*y**3*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*y*(3*x**2 - 3*y**2)*cos(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3) + 2*x*cos(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + y**2*(3*x**2 - 3*y**2)*sin(x**3 - 3*x*y**2)*cosh(3*x**2*y - y**3) + 2*y*sin(x**3 - 3*x*y**2)*sinh(3*x**2*y - y**3))*re(cos(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)) + re(sin(x + I*y)*sin(x**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) + 2*I*x*y*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3) - y**2*cos(x**3 + 3*I*x**2*y - 3*x*y**2 - I*y**3))/cos(x + I*y)**2))]
